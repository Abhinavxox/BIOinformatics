# %% [markdown]
# ## **21BIO112: Lab Assignment 5**
# Name     : Abhinav Pandey
#
# Roll No. : AM.EN.U4AIE21088

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#problem1
#finding a motif in DNA
s = input("Enter string s").upper()
t = input("Enter string t").upper()

flag = False
output = ""
for i in range(0,len(s)):
  for j in range(0,len(t)):
    if s[i+j]!=t[j]:
      flag=False
      break
    else :
      flag = True
  if flag:
    output = output + str(i+1) +" "

print(str(output))
# Out:
# Enter string sGATATATGCATATACTT
# Enter string tatat
# 2 4 10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#question2

#function to calculate hamming distance
def hamming(second, first):
  for i in range(0,  len(first)):
      distance = 0
      if first[i] != second[i]:
        distance += 1
  return distance

#input
DNA = ['TTACCTTAAC', 'GATATCTGTC', 'ACGGCGTTCG', 'CCCTAAAGAG',
'CGTCAGAGGT']
k = input("Enter pattern ")
length = len(k)

#find the distance between pattern and strings
distance = 0
for dna in DNA:
  greatest_hamming_distance = 0
  for i in range(len(dna) - length + 1):
    motif = dna[i:i + length] 
    if hamming(k, motif) > greatest_hamming_distance:
      greatest_hamming_distance = hamming(k, motif) 
  distance += greatest_hamming_distance
print(distance)
# Out:
# Enter pattern aaa
# 5

# %%
#question3
#brute force motif search

def Neighbors(pattern, d):
  if d == 0:
    return pattern
  elif len(pattern) == 1:
    return ['A', 'C', 'G', 'T']
  code = ['A', 'C', 'G', 'T']
  neighborhood = []
  suffix_neighbour = Neighbors(pattern[1:], d)
  for suffix in suffix_neighbour:
    if hamming(pattern[1:], suffix) < d:
      for base in code:
        neighborhood.append(base + suffix)
    else:
      neighborhood.append(pattern[0] + suffix)
  return neighborhood

def BruteMotifEnumeration(dna, k, d):
 patterns = []
 biglist = []
 for x in range(len(dna)):
  for i in range(len(dna[x]) - k + 1):
    kmer = dna[x][i:i + k]
    neighbors = Neighbors(kmer, d)
    patterns.extend(neighbors)
  biglist.append(set(patterns))
  patterns = []

 common_patterns = biglist[0]
 for j in range(1, len(dna)):
  common_patterns.intersection_update(biglist[j])
 return list(common_patterns)

dtxt_in = """AAGTTAAAGCTCGTCCTGCCACCGC
ATAAGTGGCACGACGGGGTGTAAGC
TGGGGTGCGGTAAGCTGCGAAGGGA
TCCCGCAAGTAGGTCAAAGCATCCA
ACGCAGGTGGATCATAGAGTAAAGC
TAAGCATCAATGTTACGTAAATGGA"""
dna_in= [y for y in (x.strip() for x in dtxt_in.splitlines()) if y]
k_in = 5
d_in = 1
Corr_out = "AAGTG GAAGC GTAAA TAAGC GTGAA CAAGC GGTAA AAAGC AGTAA"

print(" ".join(BruteMotifEnumeration(dna_in, k_in, d_in)))
# Out:
# GCCTC TTCGC CGAAA ACTCC ATACG ACGGA TCGCG GAAGG CAGTA TAGGC TCTAG GGGGA CCTGA ACAGA ATTAC ACGCG TAGGT GCCAT GCTCC GTCGA TGATT GAGGG TCCAC ATAAG GCTCT ATCCT TTTTC CGTTG CCCTC ACCTT CGAAT GGTAT TATCT TTGTT CGGAC GTTCG CTGGA AAGAG TCCGC AGTAA CTAGA CATCT GAGTC CACCC TCTAA CATTT TGGAG GTACA TGAGA CATAC TATGA TCGGC GTCCA CTCTA GAACA GCCCA CCACT GTAAC TCACG AGACG GTTGT CTG
G ATTAT GGTGC TGACT CATTC CGGTC TGATC CGTTA TAACG CCAAA GGCTT GAACG AAGAA CGGTA GAAAT TGAGG GCTTG TCTAC ATTTA CTGTG AAAGC GTCTA GTAAT TACAT GGCCT AGCGT ACGTT GTCGG TAGAT CGGGT GCGAA GTAGT TCCAG GACAC CTTTC TCCCG GAGAT GCAGG GACCA TCTCT GCCTT CTCGA CCTAT TATCC CAGAC ACTCT ATGCA TCTCA TACGT CCCCA CGATA TGGAA CTGAT TCCGT ACCCG AACGC CAGAA CCTCA GGCAG AGGCG GCTGC GCGCA TCTGA TGCGG GCCTA AACGA GATTG TGAGC GTAGA TCGAC GTTCA GCGAC ACATG AGGGA TCACA CCATA TCTGT AGGGC AATCC TGTTA TAAAT TAACA AAATT TTTAC AACTG AGGTT TACTC CACAA AAGAT ACATA CTCAT AGCTA GGTCT AGCCC GAGGT ACCGG ACGAG CAGAG GCACC ACTTG TAGAG TTGCT AACTA TTTTG TATGC CGTGC TCTCG GCGTG TGCTG TAGTG TGAAG CGCGG GGGCG AGTAT GACAA AAGTT CTGTA AGTTC TGCAA TTGGT CAACA ACCGA AACCG CTCGC GCACT TCATG AGAAT TGCAT CATAG GGGTG TTACT TCCGA AATAC ACACG GCTCA CACAG CCGAT TATTC TTTCC TGTGA AAGTG GGACC CCTAA TTAGT TTCTA TTGAG AGAGG AGGAC CCGAG ATTTC TTCTC GTCAT CGCTT ATAAT TCAGG GCCAC TTGCC ATATT GCAGA CGATC TCAAC GATAA CCGCA TGGAT TGCCT TTATA CAGCC TGGCG ATGGT GAGCG TGGGT GCAAC TGTAA ATCGC GTCTC TGACA CGTCC CTAGT CCCAG TTGGC AATCG TAATC GCCGC AGATC ATCAT TCAAT TGATG ATGCC CTCAC GGTCA AGAGT CAATT ATGGG CTAAT GTGCC ATTGC GACAG AGAGA ACACC CAGGT ATGCG TTTAT CTGCC ACCAA ACCAG AACAA CCGCC TCCAA ATATC ATTTT ACGGC CGGCA TTGAT GTTGC CATGC TACCT TTTCT TTGCG GAATC GTGAT CCTTA TCCTA GCGGC TACAA TATGG CCTCC GGACA TTGTA GTGAC GGAGT TTTGC TCATA AACCC ATCCG GACGG AGCGG GGAGC GCTAA ATGTG CTATC ACAGG GACGC CATCC TCCCC CCTCT GCTAG CACGG CGGAA GGAAG TCGTT AGCCA TATCA CTTTA TCCTC AAATG GTTAG TCCTG GTTGG CGGGC GTGAA TCGCA CTGTC GGCTC CCGCT TGCGT GTGCG ATAGC GCCC ...

# %%
#question4
#scoring motifs
from random import randrange 

#main function
def scoreMotifs(m): 
  z = zip(*m)     
  total = 0     
  for string in z: 
    score = len(string) - max([string.count('A'), 
                               string.count('C'), 
                               string.count('G'), 
                               string.count('T')])         
    total += score     
  return total 

#generate a random dna matrix
def random_seq(): 
  dna_mapping = ['T', 'A', 'C', 'G'] 
  return ''.join([dna_mapping[randrange(4)] for _ in range(3)]) 

#count matrix 
motifs = [random_seq() for _ in range(1000000)] 
print(scoreMotifs(motifs)) 

#profile matrix
motifs = ['GCG', 'AAG', 'AAG', 'ACG', 'CAA'] 
print(scoreMotifs(motifs))
# Out:
# 2247892
# 5
